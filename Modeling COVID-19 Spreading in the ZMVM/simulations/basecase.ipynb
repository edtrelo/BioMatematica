# %%
import sys
sys.path.insert(1, "D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/mathematics")

# %%
import simulaciones
import datosporregion as dpr
import model

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
plt.rcParams["animation.html"] = "jshtml"
plt.rcParams['figure.dpi'] = 200

# %%
viajes = dpr.viajes_regiones()
casos = dpr.casos_regiones()
modelo = model.SEIRDmodel(viajes, casos, propInfAislamientoTotal = 0.5)

# %%
casobase = simulaciones.gdfSimulacion(modelo)

# %%
casobase
# Out:
#         gid cve_ent                 nom_mun cve_umun  no_locs   p_total  \
# region
# 1         6      09              Cuauhtémoc    09015      1.0  531831.0
# 2         4      09            Azcapotzalco    09002      1.0  414711.0
# 3         3      09  La Magdalena Contreras    09008     13.0  239086.0
# 4       132      15                 Texcoco    15099     70.0  235151.0
# 5         1      09                 Tlalpan    09012    141.0  650567.0
# 6       102      15                Jaltenco    15044      2.0   26328.0
# 7        11      09               Iztacalco    09006      1.0  384326.0
# 8       139      15             Teotihuacán    15092     30.0   53010.0
#
#           pobmas    pobfem    p_0a2  p_0a2_m  ...  semana_5  semana_6  \
# region                                        ...
# 1       251725.0  280106.0  18953.0   9723.0  ...  0.000326  0.005937
# 2       196053.0  218658.0  14917.0   7688.0  ...  0.000187  0.002878
# ...

# %%
plt.ioff()
fig, ax = plt.subplots()

anime = simulaciones.animarMapa(casobase, ax, fig, norm = True)

matplotlib.animation.FuncAnimation(fig, anime, frames=14, interval=1000)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
