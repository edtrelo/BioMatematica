# %%
using CSV
using DataFrames
using Dates
using HypothesisTests
using Plots
using Statistics
using StatsPlots
using CurveFit

# %% [markdown]
# Vamos a usar los datos de afluencia del STC Metro para analizar la variabilidad de la movilidad de la ZMVM en el tiempo.

# %%
metrodata = CSV.read("D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/rawdata/afluenciastc_simple_02_2023.csv", DataFrame);

# %% [markdown]
# Agrupamos los datos de afluencia por fecha y los sumamos (cada fecha tiene la suma de la afluencia de cada estación).

# %%
porfecha = groupby(metrodata, :fecha)
porfecha = combine(porfecha, :afluencia => sum); # este es el equivalente a  groupby(column).sum()

# %% [markdown]
# La primer hipótesis que queremos probar es si no hay variabiliad entre la afluencia a fines de 2019 y a principios de 2020.

# %%
inicios2020 = porfecha[DateTime("2020-01-01") .<= porfecha.fecha .<= DateTime("2020-02-27"), 2];
data2019 = porfecha[DateTime("2019-01-01") .<= porfecha.fecha .<= DateTime("2019-12-31"), 2];

# %%
MannWhitneyUTest(inicios2020, data2019)
# Out:
# Approximate Mann-Whitney U test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          27475.0
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.7439
#
# Details:
#     number of observations in each group: [58, 365]
#     Mann-Whitney-U statistic:             10302.0
#     rank sums:                            [12013.0, 77663.0]
#     adjustment for ties:                  0.0
#     normal approximation (μ, σ):          (-283.0, 864.874)

# %% [markdown]
# No hay evidencia que nos haga rechazar la hipótesis.

# %% [markdown]
# Ahora queremos probar si el número esperado de usuarios en el metro en 2017 es el mismo que en el año 2020. Obtenemos los datos de afluencia de cada año.

# %%
data2017 = porfecha[DateTime("2017-01-01") .<= porfecha.fecha .<= DateTime("2017-12-31"), 2];

# %% [markdown]
# Para probar la hipótesis, usamos la prueba de Mann-Withney:

# %%
MannWhitneyUTest(data2019, data2017)
# Out:
# Approximate Mann-Whitney U test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -144898.0
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0001
#
# Details:
#     number of observations in each group: [365, 365]
#     Mann-Whitney-U statistic:             55771.0
#     rank sums:                            [122566.0, 144249.0]
#     adjustment for ties:                  504.0
#     normal approximation (μ, σ):          (-10841.5, 2848.79)

# %% [markdown]
# El $p-$value de la prueba es $p = 0.0001$ y por ello rechazamos la hipótesis. Vamos a ver cómo se distribuyen nuestros datos por medio de un boxplot:

# %%
myplot = boxplot(["2017" "2019"], [data2019, data2019], legend = false, ylabel = "Afluencia diaria",
        xtickfontsize = 14, ytickfontsize = 10, yguidefontsize = 15);
#savefig(myplot,"D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/graficaldata/distrmetro.png")

# %%
myplot

# %% [markdown]
# Podemos notar la gran cantidad de outliers, por ello queremos realizar la misma prueba pero a los datos sin estos outliers.

# %%
function iqrrange(x::Vector) 
    q1 = quantile!(x, 0.25)
    q3 = quantile!(x, 0.75)
    iqr = q3 - q1
    (q1 - 1.5*iqr, q3 + 1.5*iqr)
end
# Out:
# iqrrange (generic function with 1 method)

# %% [markdown]
# Obtenemos el rango inter cuantil de cada año

# %%
rango2017 = iqrrange(data2017)
rango2019 = iqrrange(data2019)
# Out:
# (2.516288e6, 6.518616e6)

# %% [markdown]
# Creamos un dataframe donde cada renglón se la misma fecha del año:

# %%
datos = DataFrame(año2017=data2017, año2019=data2019);

# %% [markdown]
# Filltramos los datos que se encuentren dentro de sus recpectivos rangos intercuantiles.

# %%
temp = datos[( datos.año2017 .>= rango2017[1]) .& (datos.año2017 .<= rango2017[2]), :]
datosfiltro = temp[( temp.año2019 .>= rango2019[1]) .& (temp.año2019 .<= rango2019[2]), :];

# %% [markdown]
# realizamos la misma prueba para este conjunto de datos:

# %%
MannWhitneyUTest(datosfiltro.año2017, datosfiltro.año2019)
# Out:
# Approximate Mann-Whitney U test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          120008.0
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-05
#
# Details:
#     number of observations in each group: [307, 307]
#     Mann-Whitney-U statistic:             57715.0
#     rank sums:                            [104993.0, 83812.0]
#     adjustment for ties:                  0.0
#     normal approximation (μ, σ):          (10590.5, 2197.79)

# %% [markdown]
# Debemos rechazar la hipótesis de que la distribución de los datos no ha cambiado a lo largo del tiempo. Veamos el siguiente gráfico de dispesión:

# %%
myplot = scatter(datosfiltro.año2017, datosfiltro.año2019, 
    xlabel = "Afluencia en 2017", ylabel = "Afluencia en 2019", legend = false,
    xtickfontsize = 10, ytickfontsize = 10, yguidefontsize = 15, xguidefontsize = 15);
#savefig(myplot,"D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/graficaldata/2017vs2019metro.png")

# %%
myplot

# %% [markdown]
# Podemos probar una relación lineal entre las afluencias de los años:

# %%
cor(datosfiltro.año2017, datosfiltro.año2019)
# Out:
# 0.9295833816323111

# %% [markdown]
# El coeficiente de correlación de las afluencias por año suguiere una relación lineal **fuerte**. Suponiendo esto, los parámetros de la recta que mejor se ajustan son:

# %%
a, b = linear_fit(datosfiltro.año2017, datosfiltro.año2019)
# Out:
# (35.32750484077043, 0.8144082987394422)
