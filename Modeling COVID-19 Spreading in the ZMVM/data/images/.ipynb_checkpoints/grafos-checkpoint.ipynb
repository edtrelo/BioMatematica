# %%
import networkx as nx
import matplotlib.pyplot as plt
import momepy
import geopandas as gpd
import pandas as pd
import pickle as pkl
# Out:
# C:\Users\Edgar Trejo\anaconda3\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
mapa = gpd.read_file("D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/rawdata/Censo 2010 (Municipal)/inegi_refcenmuni_2010.shp", 
                    encoding = 'latin')

# %%
with open("D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/rawdata/regiones.pkl", "rb") as file:
    regiones = pkl.load(file)

# %%
zmvm = []
for value in regiones.values():
    zmvm.extend(value)

# %%
with open("D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/rawdata/cve_umun.pkl", "wb") as handle:
    pkl.dump(zmvm, handle, protocol=pkl.HIGHEST_PROTOCOL)

# %%
mapa = mapa[mapa.cve_umun.isin(zmvm)]

# %%
mapa = mapa.iloc[mapa['nom_mun'].str.normalize('NFKD').argsort()]

# remove accents
mapa['nom_mun'] = mapa['nom_mun'].str.normalize('NFKD')\
             .str.encode('ascii', errors='ignore')\
             .str.decode('utf-8')

# %%
mapa = mapa.sort_values(by='nom_mun')

# %%
geometry = mapa.geometry

# %%
# obtenemos el centroide de la región
centros = geometry.to_crs(epsg=4087).centroid

# %%
P = lambda p: (p.x, p.y)

# %%
lats = centros.map(P).to_numpy()

# %%
pos = {}
for i in range(47):
    pos[mapa.iloc[i, 3]] = lats[i]

# %%
data = pd.read_csv("D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/cleandata/viajes/viajes_entre_semana_por_cve_umun_2017.csv",
                  index_col = 0)

# %%
with open("D:/Edgar Trejo/Universidad/BioMatematica/Modeling COVID-19 Spreading in the ZMVM/data/cleandata/ZMVM/cves_poblacion_total.pkl", "rb") as file:
    cves_pob = pkl.load(file)

# %%
mapa.sort_values(by='nom_mun', ignore_index = True)
# Out:
#      gid cve_ent                      nom_mun cve_umun  no_locs    p_total  \
# 0      7      09               Alvaro Obregon    09010      4.0   727034.0
# 1    214      15                       Apaxco    15010     18.0    27521.0
# 2    211      15         Atizapan de Zaragoza    15013      7.0   489937.0
# 3      4      09                 Azcapotzalco    09002      1.0   414711.0
# 4      5      09                Benito Juarez    09014      1.0   385439.0
# 5    199      15                       Chalco    15025     61.0   310130.0
# 6    195      15                  Chicoloapan    15029     16.0   175053.0
# 7    193      15                 Chimalhuacan    15031      6.0   614453.0
# 8    204      15      Coacalco de Berriozabal    15020      4.0   278064.0
# 9     12      09                     Coyoacan    09003      1.0   620416.0
# 10     9      09        Cuajimalpa de Morelos    09004     20.0   186391.0
# 11     6      09                   Cuauhtemoc    09015      1.0   531831.0
# 12   200      15                   Cuautitlan    15024     27.0   140059.0
# 13   111      15           Cuautitlan Izcalli    15121     10.0   511675.0
# 14   191      15          Ecatepec de Morelos    15033      4.0  1656107.0
# 15     8      09            Gustavo A. Madero    09005      1.0  1185772.0
# 16   189      15                   Huehuetoca    15035     25.0   100023.0
# 17   187      15                 Huixquilucan    15037     60.0   242167.0
# 23  Población de 100 mil a 1 millón de habitantes
# 24  Población de 100 mil a 1 millón de habitantes
# 25  Población de 100 mil a 1 millón de habitantes
# 26  Población de 100 mil a 1 millón de habitantes
# 27     Población de más de 1 millón de habitantes
# 28  Población de 100 mil a 1 millón de habitantes
# 29        Población de 15 mil a 50 mil habitantes
# 30  Población de 100 mil a 1 millón de habitantes
# 31        Población de 10 mil a 15 mil habitantes
# 32       Población de 50 mil a 100 mil habitantes
# 33       Población de 50 mil a 100 mil habitantes
# 34       Población de 50 mil a 100 mil habitantes
# 35  Población de 100 mil a 1 millón de habitantes
# 36        Población de 15 mil a 50 mil habitantes
# 37       Población de 50 mil a 100 mil habitantes
# 38  Población de 100 mil a 1 millón de habitantes
# 39  Población de 100 mil a 1 millón de habitantes
# 40  Población de 100 mil a 1 millón de habitantes
# 41       Población de 50 mil a 100 mil habitantes
# 42  Población de 100 mil a 1 millón de habitantes
# 43  Población de 100 mil a 1 millón de habitantes
# 44  Población de 100 mil a 1 millón de habitantes
# 45  Población de 100 mil a 1 millón de habitantes
# 46  Población de 100 mil a 1 millón de habitantes
#
#                                              geometry
# 0   POLYGON ((-99.18906 19.39559, -99.18871 19.394...
# 1   POLYGON ((-99.11815 20.02704, -99.11815 20.025...
# 2   POLYGON ((-99.26311 19.52747, -99.26307 19.527...
# 3   POLYGON ((-99.15718 19.50285, -99.15695 19.502...
# 4   POLYGON ((-99.14350 19.35724, -99.14386 19.357...
# 5   POLYGON ((-98.71372 19.31548, -98.71293 19.314...
# 6   POLYGON ((-98.79921 19.40503, -98.79938 19.404...
# 7   POLYGON ((-98.96381 19.37372, -98.96412 19.373...
# 8   POLYGON ((-99.12384 19.64241, -99.12370 19.642...
# 9   POLYGON ((-99.18079 19.34714, -99.18076 19.347...
# 10  POLYGON ((-99.25738 19.40112, -99.25698 19.400...
# 11  POLYGON ((-99.17439 19.40452, -99.17487 19.404...
# 12  POLYGON ((-99.17519 19.69386, -99.17518 19.694...
# 13  POLYGON ((-99.18473 19.63359, -99.18474 19.632...
# 14  POLYGON ((-99.06199 19.65780, -99.06184 19.657...
# 15  POLYGON ((-99.11789 19.59059, -99.11860 19.584...
# 16  POLYGON ((-99.19485 19.88909, -99.19426 19.887...
# 17  POLYGON ((-99.27617 19.43269, -99.27595 19.432...
# 18  POLYGON ((-98.66328 19.39927, -98.66147 19.398...
# 19  POLYGON ((-99.05579 19.42214, -99.05584 19.421...
# 20  POLYGON ((-99.05813 19.40072, -99.05814 19.400...
# 21  MULTIPOLYGON (((-99.09852 19.76401, -99.09709 ...
# 22  POLYGON ((-99.24489 19.27621, -99.24476 19.276...
# 23  POLYGON ((-98.93892 19.38648, -98.93789 19.386...
# 24  POLYGON ((-99.16371 19.45643, -99.16372 19.456...
# 25  POLYGON ((-98.99718 19.22747, -98.99723 19.227...
# 26  POLYGON ((-99.28555 19.53647, -99.28566 19.535...
# 27  POLYGON ((-98.99103 19.42463, -98.99067 19.424...
# 28  POLYGON ((-99.51655 19.57384, -99.51699 19.574...
# 29  POLYGON ((-98.78754 19.05676, -98.78746 19.056...
# 30  POLYGON ((-98.96027 19.80299, -98.95996 19.802...
# 31  POLYGON ((-98.88320 19.22368, -98.88247 19.222...
# 32  POLYGON ((-99.19776 19.74735, -99.19818 19.747...
# 33  POLYGON ((-98.82862 19.69339, -98.82844 19.693...
# 34  POLYGON ((-99.22643 19.78949, -99.22492 19.787...
# 35  POLYGON ((-98.95398 19.51248, -98.95317 19.512...
# 36  POLYGON ((-98.89768 19.59854, -98.89753 19.597...
# 37  POLYGON ((-98.95071 19.90545, -98.95073 19.904...
# 38  POLYGON ((-98.97893 19.32393, -98.97856 19.323...
# 39  MULTIPOLYGON (((-99.08857 19.53773, -99.08848 ...
# 40  POLYGON ((-99.19671 19.30240, -99.19629 19.302...
# 41  POLYGON ((-99.12028 19.65313, -99.12036 19.653...
# 42  MULTIPOLYGON (((-99.12028 19.65313, -99.12029 ...
# 43  POLYGON ((-98.95303 19.33463, -98.95237 19.333...
# 44  POLYGON ((-99.11690 19.45783, -99.11674 19.457...
# 45  POLYGON ((-99.13301 19.21010, -99.13832 19.215...
# 46  POLYGON ((-99.00832 19.84694, -99.00131 19.835...
#
# [47 rows x 193 columns]

# %%
pob = cves_pob.values()

# %%
G = nx.Graph()

for i in range(47):
    for j in range(47):
        u = mapa.iloc[i, 3]
        v = mapa.iloc[j, 3]
        if i == j or data.iloc[i, j] == 0:
            pass
        else:
            G.add_edge(u, v)
            G[u][v]['weight'] = data.iloc[i, j]

# %%
entradas = data.sum().to_numpy()

# %%
entradas = entradas/entradas.sum()

# %%
salidas = data.sum(axis = 1).to_numpy()

# %%
salidas = salidas/salidas.sum()

# %%
labels = {}

for i in range(47):
    labels[mapa.iloc[i, 3]] = '{}'.format(i+1)

# %%
degrees = [len([j for j in G.neighbors(n)]) + 1 for n in labels.keys()]

# %%
D = {}

for k in degrees:
    if k not in D:
        D[k] = 1
    else:
        D[k] += 1

# %%
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)

# %%
data.iloc[0, 0]
# Out:
# 256156

# %%
fig, ax = plt.subplots()

ax.bar(*np.unique(degree_sequence, return_counts=True))
ax.set_title("Degree histogram")
ax.set_xlabel("Degree")
ax.set_ylabel("# of Nodes")
# Out:
# Text(0, 0.5, '# of Nodes')

# %%
import numpy as np
fig, ax = plt.subplots(1, 2)

alldata = np.concatenate((salidas, entradas))
vmax = alldata.max()
vmin = alldata.min()

nx.draw(G, ax=ax[0], pos = pos, labels = labels, node_color = salidas, font_size=14, font_color="k", cmap ="autumn_r",
       vmin = vmin, vmax=vmax)
nx.draw(G, ax=ax[1], pos = pos, labels = labels, node_color = entradas, font_size=14, font_color="k", cmap ="autumn_r",
       vmin = vmin, vmax=vmax)

fig.set_size_inches(14, 8)
sm = plt.cm.ScalarMappable(cmap="autumn_r", norm=plt.Normalize(vmin = vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm, fraction = 0.04)
cbar.ax.tick_params(labelsize=15) 
cbar.set_label(label='\nViajes realizados', fontsize=18)

ax[0].annotate('(A)', xy=(20, 460), xycoords = 'axes points', fontsize = 15)
ax[1].annotate('(B)', xy=(20, 460), xycoords = 'axes points', fontsize = 15)

fig.tight_layout(pad = 0.5)
plt.show()
